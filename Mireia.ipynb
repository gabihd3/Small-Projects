# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import re
import seaborn as sns
sns.set()

# %%
data = pd.read_csv('Merged final - copia.csv', sep=';')
print(type(data))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
data.head()
# Out:
#   Participant Public ID         Question Key Response
# 0              9po4wizk  BEGIN QUESTIONNAIRE      NaN
# 1              9po4wizk                demo1       25
# 2              9po4wizk                demo2     Male
# 3              9po4wizk                demo3       No
# 4              9po4wizk         response-1.1   Callum

# %%
data.shape
# Out:
# (6604, 3)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6604 entries, 0 to 6603
# Data columns (total 3 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Participant Public ID  6602 non-null   object
#  1   Question Key           6602 non-null   object
#  2   Response               5351 non-null   object
# dtypes: object(3)
# memory usage: 154.9+ KB

# %%
#for col in data:
    #print((data[col].unique()))

# %%
part = data['Participant Public ID'].nunique()
print('Unique participants:', part)

options = data['Response'].nunique()
print('options', options)
# Out:
# Unique participants: 40
# options 1219

# %%
twoone=(data.loc[data['Question Key'].isin(['response-18.1-quantised'])])

arr = np.array(twoone)
lista = arr.tolist()

total = [i[2] for i in lista]

one = [i[2] for i in lista if i[2] == '1']
two = [i[2] for i in lista if i[2] == '2']
three = [i[2] for i in lista if i[2] == '3']

sum_lenghts = (len(one)+(len(two)+(len(three))))


print('\t','1:', len(one), '\n\t', '2:', len(two), '\n\t', '3:', len(three), '\n',)
print('Total', sum_lenghts)


if sum_lenghts != len(lista):
    print('something went wrong')
else:
    pass

plt.hist(total)
plt.title('Response-12.1')
plt.subplot().set_xlabel(f'[1:{len(one)}]     [2: {len(two)}]      [3: {len(three)}]')
plt.savefig('response-18.1.png')
# Out:
# 	 1: 0
# 	 2: 39
# 	 3: 1
#
# Total 40

# %%
for i in range(1,sum_lenghts + 1):
    twoone=(data.loc[data['Question Key'].isin([f'response-{i}.1-quantised'])])

    arr = np.array(twoone)
    lista = arr.tolist()

    total = [i[2] for i in lista]

    one = [i[2] for i in lista if i[2] == '1']
    two = [i[2] for i in lista if i[2] == '2']
    three = [i[2] for i in lista if i[2] == '3']

    sum_lenghts = (len(one)+(len(two)+(len(three))))

    if sum_lenghts != len(lista):
        print('something went wrong')
    else:
        pass

    plt.hist(total)
    plt.title(f'Response-{i}.1')
    plt.subplot().set_xlabel(f'[1:{len(one)}]    [2: {len(two)}]    [3: {len(three)}]')
    #plt.savefig(f'response-{i}.1.png')
    plt.show()
